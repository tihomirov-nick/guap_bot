# %%
import requests
from bs4 import BeautifulSoup

url = 'https://guap.ru/rasp/?g=189'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
from collections import defaultdict

schedule = defaultdict(list)
current_day = None

found_h3 = False

for tag in soup.find_all(['h3', 'h4', 'div']):
    if tag.name == 'h3':
        found_h3 = True
        current_day = tag.text
    elif found_h3:
        schedule[current_day].append(tag.text)

for day, lessons in schedule.items():
    print(day)
    for lesson in lessons:
        print(lesson)
    print()
# Out:
# Вне сетки расписания
# вне сетки расписания (—)
# КП – Основы систем Интернета вещей  – , ауд. на базе кафедры КАФЕДРА 33Группа: 3131
# Группа: 3131
#
# Понедельник
# 1 пара (9:30–11:00)
# ▼ Л – Математическая логика и теория алгоритмов  – Б.Морская 67, ауд. 52-43Преподаватель: Беззатеев С.В. - заведующий кафедрой, д-р техн. наук, доцентГруппы: 3131; 3132; 3136
# Преподаватель: Беззатеев С.В. - заведующий кафедрой, д-р техн. наук, доцентГруппы: 3131; 3132; 3136
# 2 пара (11:10–12:40)
# ▼ Л – Электроника  – Б.Морская 67, ауд. 52-43Преподаватель: Литвинов Ю.В. - доцент, канд. техн. наук, доцентГруппы: 3131; 3132; 3136
# Преподаватель: Литвинов Ю.В. - доцент, канд. техн. наук, доцентГруппы: 3131; 3132; 3136
# 3 пара (13:00–14:30)
# ▲ Л – Математическая логика и теория алгоритмов  – Б.Морская 67, ауд. 52-43Преподаватель: Беззатеев С.В. - заведующий кафедрой, д-р техн. наук, доцентГруппы: 3131; 3132; 3136
# Преподаватель: Беззатеев С.В. - заведующий кафедрой, д-р техн. наук, доцентГруппы: 3131; 3132; 3136
# ▼ Л – Корпоративная защита от внутренних угроз информационной безопасности  – Б.Морская 67, ауд. 52-43Преподаватель: Коломойцев В.С. - доцент, канд. техн. наукГруппы: 3131; 3132; 3136
# Преподаватель: Коломойцев В.С. - доцент, канд. техн. наукГруппы: 3131; 3132; 3136
# 4 пара (15:00–16:30)
# Л – Алгоритмические проблемы криптографии  – Б.Морская 67, ауд. 52-43Преподаватель: Афанасьева А.В. - старший преподавательГруппы: 3131; 3132; 3136
# Преподаватель: Афанасьева А.В. - старший преподавательГруппы: 3131; 3132; 3136
# 5 пара (16:40–18:10)
# ▼ Л – Технологии и методы программирования  – Б.Морская 67, ауд. 21-18Преподаватель: Фомичева С.Г. - профессор, канд. техн. наук, профессорГруппы: 3131; 3132; 3136
# Преподаватель: Фомичева С.Г. - профессор, канд. техн. наук, профессорГруппы: 3131; 3132; 3136
#
# Среда
# 1 пара (9:30–11:00)
# Преподаватель: Гончарова В.И. - ассистентГруппа: 3131
#
# Пятница
# 2 пара (11:10–12:40)
# ЛР – Математическая логика и теория алгоритмов  – Б.Морская 67, ауд. 52-44Преподаватель: Красников Н.С.  - ассистентГруппа: 3131
# Преподаватель: Красников Н.С.  - ассистентГруппа: 3131
# 3 пара (13:00–14:30)
# ▲ ЛР – Корпоративная защита от внутренних угроз информационной безопасности  – Б.Морская 67, ауд. 52-48Преподаватель: Дубинина А.В. - ассистентГруппа: 3131
# Преподаватель: Дубинина А.В. - ассистентГруппа: 3131
# ▼ ПР – Алгоритмические проблемы криптографии  – Б.Морская 67, ауд. 14-42Преподаватель: Афанасьева А.В. - старший преподавательГруппа: 3131
# Преподаватель: Афанасьева А.В. - старший преподавательГруппа: 3131
#
# Суббота
# 3 пара (13:00–14:30)
# ЛР – Технологии и методы программирования  – Б.Морская 67, ауд. 52-44Преподаватель: Дубинин А.И. - ассистентГруппа: 3131
# Преподаватель: Дубинин А.И. - ассистентГруппа: 3131
# 4 пара (15:00–16:30)
# ПР – Прикладная физическая культура (элективный модуль)  – Б.Морская 67, ауд. спортзал*Преподаватели: Башкин В.М. - заведующий кафедрой, д-р пед. наук, доцент; Борисенок А.А. - старший преподаватель; Евгеньев А.А. - доцент, канд. пед. наук; Фарберов М.Б. - доцент, канд. техн. наук, доцент; Шубин Е.Г. - доцент, канд. пед. наук, доцентГруппы: 3131; 3132; 3133; 3135; 3136
# Преподаватели: Башкин В.М. - заведующий кафедрой, д-р пед. наук, доцент; Борисенок А.А. - старший преподаватель; Евгеньев А.А. - доцент, канд. пед. наук; Фарберов М.Б. - доцент, канд. техн. наук, доцент; Шубин Е.Г. - доцент, канд. пед. наук, доцентГруппы: 3131; 3132; 3133; 3135; 3136
# 5 пара (16:40–18:10)
# ▲ Л – Документоведение и конфиденциальное делопроизводство  – Б.Морская 67, ауд. 21-18Преподаватель: Воронов А.В. - доцент, канд. техн. наукГруппы: 3131; 3132; 3136
# Преподаватель: Воронов А.В. - доцент, канд. техн. наукГруппы: 3131; 3132; 3136
# 6 пара (18:30–20:00)
# ▲ ЛР – Корпоративная защита от внутренних угроз информационной безопасности  – Б.Морская 67, ауд. 52-48Преподаватель: Дубинина А.В. - ассистентГруппа: 3131
# Преподаватель: Дубинина А.В. - ассистентГруппа: 3131
# ▼ ПР – Документоведение и конфиденциальное делопроизводство  – Б.Морская 67, ауд. 52-48Преподаватель: Воронов А.В. - доцент, канд. техн. наукГруппа: 3131
# Преподаватель: Воронов А.В. - доцент, канд. техн. наукГруппа: 3131
